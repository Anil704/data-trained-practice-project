# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
df = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # EDA

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
#regression problem

# %%
df['AB'].unique()
# Out:
# array([5575, 5467, 5439, 5533, 5605, 5509, 5567, 5485, 5640, 5511, 5459,
#        5417, 5544, 5600, 5484, 5631, 5491, 5480, 5571, 5527, 5428, 5463,
#        5420, 5529, 5385, 5565, 5649, 5457, 5572], dtype=int64)

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#no encoding because numerical values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#no null values proceed data set

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#data visulazation

# %%
sns.scatterplot(data=df,x='W',y='R')
plt.show()

# %%
sns.scatterplot(data=df,x='W',y='AB')
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
sns.scatterplot(data=df,x='W',y='H')
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
sns.relplot(data=df,x='W',y='2B')

# %%
sns.relplot(data=df,x='W',y='HR')

# %%
sns.scatterplot(data=df,x='W',y='ERA')
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %%
sns.relplot(data=df,x='W',y='SHO')

# %%
sns.scatterplot(data=df,x='W',y='SV')
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
sns.relplot(data=df,x='W',y='E')

# %%
sns.histplot(data=df,x='W',y='R')
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
df.hist(color = 'b',alpha = 0.51, figsize=(10,5))
plt.show()

# %%
sns.pairplot(df)

# %%
corr_mat = df.corr()
corr_mat
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
#boxplot

# %%
collist=df.columns.values
ncol=3
nrows=6
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue')
    plt.tight_layout()

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
dfCountCols = df[['R','AB','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']]

# %%
from scipy.stats import zscore
z = np.abs(zscore(dfCountCols))
df_new=df[(z<3).all(axis=1)]

# %%
print("shape before and after")
print("shape before".ljust(20),":", df.shape)
print("shape after".ljust(20),":", df_new.shape)
print("Percentage Loss".ljust(20),":", (df.shape[0]-df_new.shape[0])/df.shape[0])
# Out:
# shape before and after
# shape before         : (30, 17)
# shape after          : (29, 17)
# Percentage Loss      : 0.03333333333333333

# %%
#Q1 = df.quantile(0.25)
#Q3 = df.quantile(0.75)
#IQR = Q3 - Q1
#df_new = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
dfCountCols = df[['R','AB','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']]

# %%
Q1 = dfCountCols.quantile(0.25)
Q3 = dfCountCols.quantile(0.75)
IQR = Q3 - Q1
df_new1 = df[~((dfCountCols < (Q1 - 1.5 * IQR)) |(dfCountCols > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print("shape before and after")
print("shape before".ljust(20),":", df.shape)
print("shape after".ljust(20),":", df_new1.shape)
print("Percentage Loss".ljust(20),":", (df.shape[0]-df_new1.shape[0])/df.shape[0])
# Out:
# shape before and after
# shape before         : (30, 17)
# shape after          : (20, 17)
# Percentage Loss      : 0.3333333333333333

# %%
#less loss consider z score

# %%
x = df.drop(columns=['W'],axis=1)
y = df['W']

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x)

# %%
df_new=pd.DataFrame(df_new,columns=x.columns)

# %%
df_new.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %%
#remove skewness above data set

# %%
# so data cleaning complete so proceed ml

# %%
x = df.drop(columns=['W'],axis=1)
y = df['W']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
scaler = StandardScaler()
x_scaler = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y,test_size = 0.30,random_state=83)

# %%
lr=LinearRegression()
kn=KNeighborsRegressor()
sv=SVR()
gb=GradientBoostingRegressor()

# %%
lr.fit(x_train,y_train)
y_pred =lr.predict(x_test)
print('r2 score',r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# r2 score 0.8342767995497551
# 3.459167424174129
# 14.620469017499383
# 0.040755406674662355

# %%
kn.fit(x_train,y_train)
y_pred = kn.predict(x_test)
print('r2 score',r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(cross_val_score(kn,x,y,cv=5).mean())
# Out:
# r2 score 0.36418136020151126
# 5.977777777777779
# 56.09333333333334
# -0.7073796844198347

# %%
sv.fit(x_train,y_train)
y_pred = sv.predict(x_test)
print('r2 score',r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(cross_val_score(sv,x,y,cv=5).mean())
# Out:
# r2 score 0.028419748119811516
# 8.10472705338003
# 85.71496888809662
# -0.45819886720715275

# %%
gb.fit(x_train,y_train)
y_pred = gb.predict(x_test)
print('r2 score,',r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(cross_val_score(gb,x,y,cv=5).mean())
# Out:
# r2 score, -0.5430838236632334
# 9.611563767214557
# 136.13428399873413
# -1.0912454905853664

# %%
# hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_neighbors':[2,5,8,4,13],
              'weights':['uniform','distance'],
              'algorithm':['auto','ball_tree','kd_tree','brute'],
              'leaf_size':[30,2,6,8,9,23,21,29]}
              
gridsearch = GridSearchCV(estimator=kn,param_grid=param_grid,cv=5)
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [30, 2, 6, 8, 9, 23, 21, 29],
#                          'n_neighbors': [2, 5, 8, 4, 13],
#                          'weights': ['uniform', 'distance']})

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 4, 'weights': 'uniform'}

# %%
Final_mod = KNeighborsRegressor(algorithm='auto',leaf_size=30,n_neighbors=4,weights='uniform')
Final_mod.fit(x_train,y_train)
pred = Final_mod.predict(x_test)
r2=r2_score(y_test,pred)
print(r2*100)
# Out:
# 41.9867758186398

# %%
import joblib
joblib.dump(Final_mod,'base ball.pkl')
# Out:
# ['base ball.pkl']
